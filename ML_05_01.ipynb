# %% [markdown]
# <a href="https://colab.research.google.com/github/lihui1625/machineLearning/blob/main/ML_05_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = 2*np.random.rand(100,1)
y = 4 + 3*X + np.random.rand(100,1)

plt.axis([0, 2, 0, 15])
plt.plot(X, y, "b.")

# %%
X_b = np.c_[np.ones((100,1)), X]
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print(theta_best)
# Out:
# [[4.46623708]
#  [3.05078234]]

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2,1)), X_new]
y_predict = X_new_b.dot(theta_best)
print(y_predict)
# Out:
# [[ 4.46623708]
#  [10.56780177]]

# %%
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
print(lin_reg.intercept_, lin_reg.coef_)

y_predict_2 = lin_reg.predict(X_new)
print(y_predict_2)
# Out:
# [4.46623708] [[3.05078234]]
# [[ 4.46623708]
#  [10.56780177]]

# %%
plt.plot(X_new, y_predict_2, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()
